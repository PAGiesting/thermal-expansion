# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
df100 = pd.read_csv('data/8.1mm/oligTanz100s1r1-8c.csv')

# %%
type(df100)
# Out:
# pandas.core.frame.DataFrame

# %%
df100.head()
# Out:
#    Unnamed: 0  Temp./°C  Time/min     dL/Lo  Certificate  Standard  Corrected  \
# 0           0    19.021   0.00000 -0.000001     0.000059 -0.000456   0.000514
# 1           0    19.521   3.04405 -0.000007     0.000062 -0.000448   0.000503
# 2           0    20.021   3.39071 -0.000018     0.000065 -0.000440   0.000487
# 3           0    20.521   3.64194 -0.000027     0.000068 -0.000433   0.000473
# 4           0    21.021   3.84818 -0.000035     0.000070 -0.000425   0.000461
#
#    delT  EngAlpha    Fitted         Alpha
# 0   0.0       inf -0.000048 -6.069308e-07
# 1   0.5  0.001006 -0.000048 -5.936197e-07
# 2   1.0  0.000487 -0.000048 -5.803247e-07
# 3   1.5  0.000316 -0.000049 -5.670458e-07
# 4   2.0  0.000230 -0.000049 -5.537829e-07

# %%
df010 = pd.read_csv('data/8.1mm/oligTanz010s2r1-9c.csv')
df001 = pd.read_csv('data/8.1mm/oligHawk001s1r1-7c.csv')

# %%
col01 = df100.columns[1]
col01
# Out:
# 'Temp./°C'

# %%
plt.plot(df100[col01],df100['Alpha'],lw=2,c='r')
plt.plot(df010[col01],df010['Alpha'],lw=2,c='g')
plt.plot(df001[col01],df001['Alpha'],lw=2,c='b')

# %%
os.stat('data')
# Out:
# os.stat_result(st_mode=16895, st_ino=10133099161628877, st_dev=2181425145, st_nlink=1, st_uid=0, st_gid=0, st_size=24576, st_atime=1596230274, st_mtime=1596230274, st_ctime=1596120673)

# %%
for root, dirs, files in os.walk('data'):
    print(root,dirs)
# Out:
# data ['14.1mm-083019', '14.1mm-102218', '16.6mm-091419', '16.6mm-102819', '8.1mm']
# data\14.1mm-083019 []
# data\14.1mm-102218 []
# data\16.6mm-091419 []
# data\16.6mm-102819 []
# data\8.1mm []
